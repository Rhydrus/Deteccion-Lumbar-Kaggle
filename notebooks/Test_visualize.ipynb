# %%
import sys
import os

sys.path.append(r"C:\Users\Carlo\Desktop\Proyectos\Lumbar")
sys.path.append(os.path.abspath(r"C:\Users\Carlo\Desktop\Proyectos\src"))

# %%
from src.visualization.LumbarVisualize import Visualize
from src.visualization.LumbarVisualize import coordinates_pathologies
from src.visualization.LumbarVisualize import lumbar_coordinates

# %%
Visualize("4003253")

# %%
coordinates_pathologies("4646740")
# Out:
# Only showing severe cases for this patient
# Available keys in patient_object: dict_keys(['3201256954', '3486248476', '3666319702'])

# %%
lumbar = lumbar_coordinates(
    r"C:\Users\Carlo\Desktop\Proyectos\Lumbar\data\raw_data\train_images",

    r"C:\Users\Carlo\Desktop\Proyectos\Lumbar\data\csv\train_series_descriptions.csv",

    r"C:\Users\Carlo\Desktop\Proyectos\Lumbar\data\csv\coords_rsna_improved.csv",

)

# %%
lumbar.coordinate_visualise(
    r"C:\Users\Carlo\Desktop\Proyectos\Lumbar\data\raw_data\train_images",

    "axial",

    False,

)
# Out:
# -------------------------  STUDY_ID: 153831832, SERIES_ID: 2054214528  -------------------------
# -------------------------  STUDY_ID: 200852737, SERIES_ID: 680111404  -------------------------
